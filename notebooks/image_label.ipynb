# %%
# !pip install --upgrade google-genai
# !pip install langchain-google-genai google-generativeai
# Out:
# Requirement already satisfied: google-genai in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (2.38.0)
# Requirement already satisfied: pydantic<3.0.0dev,>=2.0.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.28.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.0dev,>=13.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (14.2)
# Requirement already satisfied: typing-extensions<5.0.0dev,>=4.11.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (2024.7.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-genai) (0.6.1)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\trjmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-google-genai in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.0.9)
# Requirement already satisfied: google-generativeai in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.4)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai) (0.3.35)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai) (2.10.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.161.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.67.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: colorama in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (0.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.7.4)
# Requirement already satisfied: anyio in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\trjmu\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (1.3.1)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\trjmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from google import genai
from google.genai import types
import base64

def generate():
  client = genai.Client(
      vertexai=True,
      project="ragprojects",
      location="us-central1",
  )

  image1 = types.Part.from_uri(
      file_uri="https://fwuwojlpuapawpahsboy.supabase.co/storage/v1/object/public/images/c78b2dcc-9522-45e5-914c-8e3e2cdf7958/photos/63ADtEwpQzjX9ux9PEQ44.jpg",
      mime_type="image/jpeg",
  )
  textsi_1 = """You are an expert event image analyst, tasked with providing a detailed and descriptive summary of the action occurring within event photographs (weddings, parties, festivals, etc.). Your goal is to capture the essence of the moment, describing \"what is happening\" as precisely as possible, for use in a multimodal Retrieval Augmented Generation (RAG) system.

**Instructions:**

1.  **Event Identification:** Determine the type of event depicted (e.g., birthday, concert, graduation).
2.  **Action Analysis:** Focus on the actions taking place. Describe \"what is happening\" in the image with specific details.
    * Who is doing what?
    * What are the subjects' interactions?
    * What are the subjects' expressions and body language?
    * What is the primary action being captured?
3.  **Key Moment Emphasis:** Highlight the most significant action or interaction that defines the moment.
4.  **Object and People Identification (Contextual):** Identify key objects and people directly involved in the action.
5.  **Scene Setting (Brief):** Briefly describe the setting to provide context for the action, but prioritize the description of \"what is happening.\"
6.  **Visual Details (Action-Related):** Include visual details that enhance the description of the action, such as:
    * Direction of movement.
    * Points of focus
    * Relevant visual cues that explain the action
7.  **Emotional Context (Implied):** If the action clearly conveys an emotion, mention it briefly to enhance the understanding of \"what is happening.\"
8.  **Conciseness and Clarity:** Describe the action succinctly and clearly, focusing on conveying the immediate event.
9.  **Objective Description:** Avoid subjective interpretations or opinions. Focus solely on describing the observable actions.
10. **Focus on visual facts:** only describe what can be seen.
11. **Output format:** Output the description as a single paragraph of text.

**Example:**

**Image:** A photo of a bride and groom cutting a wedding cake, both smiling.

**Your Description:** \"The bride and groom are actively cutting a multi-tiered wedding cake together. The bride holds the knife handle with her right hand, and the groom places his hand over hers, guiding the cut. They both display smiles, indicating joy. The cake is the central object, and the action highlights a traditional wedding moment. The scene shows the couple participating in a shared activity.\"

**Image:** a crowd of people with their hands raised in the air at a concert.

**Your Description:** \"A large crowd of people have raised their hands into the air. The crowd is densely packed, and the raised hands fill the frame. This action indicates participation in a concert or large event. The general direction of the hands is upwards. A few people can be seen holding cell phones.\"

**Now, analyze the provided event image and describe \"what is happening\" in detail.**"""

  model = "gemini-2.0-flash-001"
  contents = [
    types.Content(
      role="user",
      parts=[
        image1,
        types.Part.from_text(text=""".""")
      ]
    )
  ]
  generate_content_config = types.GenerateContentConfig(
    temperature = 1,
    top_p = 0.95,
    max_output_tokens = 2500,
    response_modalities = ["TEXT"],
    safety_settings = [types.SafetySetting(
      category="HARM_CATEGORY_HATE_SPEECH",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_DANGEROUS_CONTENT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_HARASSMENT",
      threshold="OFF"
    )],
    response_mime_type = "application/json",
    response_schema = {"type":"OBJECT","properties":{"response":{"type":"STRING"}}},
    system_instruction=[types.Part.from_text(text=textsi_1)],
  )

  for chunk in client.models.generate_content_stream(
    model = model,
    contents = contents,
    config = generate_content_config,
    ):
    print(chunk.text, end="")

generate()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 91
#      84   for chunk in client.models.generate_content_stream(
#      85     model = model,
#      86     contents = contents,
#      87     config = generate_content_config,
#      88     ):
#      89     print(chunk.text, end="")
# ---> 91 generate()
#
# Cell In[8], line 84, in generate()
#      52 contents = [
#      53   types.Content(
#      54     role="user",
#    (...)
#      59   )
#      60 ]
#      61 generate_content_config = types.GenerateContentConfig(
#      62   temperature = 1,
#      63   top_p = 0.95,
#    (...)
#      81   system_instruction=[types.Part.from_text(text=textsi_1)],
#      82 )
# ---> 84 for chunk in client.models.generate_content_stream(
#      85   model = model,
#      86   contents = contents,
#      87   config = generate_content_config,
#      88   ):
#      89   print(chunk.text, end="")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\models.py:4808, in Models.generate_content_stream(self, model, contents, config)
#    4802 function_map = _extra_utils.get_function_map(config)
#    4804 if i == 1:
#    4805   # First request gets a function call.
#    4806   # Then get function response parts.
#    4807   # Yield chunks only if there's no function response parts.
# -> 4808   for chunk in response:
#    4809     if not function_map:
#    4810       yield chunk
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\models.py:3892, in Models._generate_content_stream(self, model, contents, config)
#    3889 request_dict = _common.convert_to_dict(request_dict)
#    3890 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3892 for response_dict in self._api_client.request_streamed(
#    3893     'post', path, request_dict, http_options
#    3894 ):
#    3896   if self._api_client.vertexai:
#    3897     response_dict = _GenerateContentResponse_from_vertex(
#    3898         self._api_client, response_dict
#    3899     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_api_client.py:474, in ApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#     463 def request_streamed(
#     464     self,
#     465     http_method: str,
#    (...)
#     468     http_options: HttpOptionsDict = None,
#     469 ):
#     470   http_request = self._build_request(
#     471       http_method, path, request_dict, http_options
#     472   )
# --> 474   session_response = self._request(http_request, stream=True)
#     475   for chunk in session_response.segments():
#     476     yield chunk
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_api_client.py:385, in ApiClient._request(self, http_request, stream)
#     377   authed_session.stream = stream
#     378   response = authed_session.request(
#     379       http_request.method.upper(),
#     380       http_request.url,
#    (...)
#     383       timeout=http_request.timeout,
#     384   )
# --> 385   errors.APIError.raise_for_response(response)
#     386   return HttpResponse(
#     387       response.headers, response if stream else [response.text]
#     388   )
#     389 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\errors.py:100, in APIError.raise_for_response(cls, response)
#      98 status_code = response.status_code
#      99 if 400 <= status_code < 500:
# --> 100   raise ClientError(status_code, response)
#     101 elif 500 <= status_code < 600:
#     102   raise ServerError(status_code, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': "Permission 'aiplatform.endpoints.predict' denied on resource '//aiplatform.googleapis.com/projects/ragprojects/locations/us-central1/publishers/google/models/gemini-2.0-flash-001' (or it may not exist).", 'status': 'PERMISSION_DENIED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'IAM_PERMISSION_DENIED', 'domain': 'aiplatform.googleapis.com', 'metadata': {'resource': 'projects/ragprojects/locations/us-central1/publishers/google/models/gemini-2.0-flash-001', 'permission': 'aiplatform.endpoints.predict'}}]}}
